# %%
# Making the imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# %%
# Preprocessing Input data
data = pd.read_csv('data.csv')
X = data.iloc[:, 1]
Y = data.iloc[:, 2]
plt.scatter(X, Y)
plt.show()

# %%
# Building the model
m = 0
c = 0


L = 0.0001  # The learning Rate
epochs = 50  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c

print (m, c)
# Out:
# 1.4788617415596048 0.032071920800651646

# %%
# Making predictions
Y_pred = m*X + c

plt.scatter(X, Y) 
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
plt.show()
print(max(Y))
# Out:
# 118.5912173

# %%
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import metrics
#from sklearn.cross_validation import train_test_split
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# read data into a DataFrame
datax = pd.read_csv(r'C:\Users\VinceCreed\datasciencecoursera\Advertising.csv', index_col=0)
datax.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Sales ~ TV', data=datax).fit()

# print the coefficients
lm1.params
# Out:
# Intercept    7.032594
# TV           0.047537
# dtype: float64

# %%
### SCIKIT-LEARN ###

# create X and y
feature_cols = ['TV']
X = datax[feature_cols]
y = datax.Sales

# instantiate and fit
lm2 = LinearRegression()
lm2.fit(X, y)

# print the coefficients
print(lm2.intercept_)
print(lm2.coef_)
# Out:
# 7.032593549127693
# [0.04753664]

# %%
# read data into a DataFrame
dataxx = pd.read_csv(r'C:\Users\VinceCreed\datasciencecoursera\data.csv', index_col=0)
dataxx.head()
# Out:
#            X          Y
# 1  32.502345  31.707006
# 2  53.426804  68.777596
# 3  61.530358  62.562382
# 4  47.475640  71.546632
# 5  59.813208  87.230925

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Y ~ X', data=dataxx).fit()

# print the coefficients
lm1.params
# Out:
# Intercept    7.991021
# X            1.322431
# dtype: float64

# %%
### SCIKIT-LEARN ###

# create X and y
feature_cols = ['X']
X = dataxx[feature_cols]
y = dataxx.Y

# instantiate and fit
lm2 = LinearRegression()
lm2.fit(X, y)

# print the coefficients
print(lm2.intercept_)
print(lm2.coef_)
# Out:
# 7.991020985734465
# [1.32243102]

# %%
sns.pairplot(dataxx, x_vars=['X'], y_vars='Y', height=7, aspect=0.7, kind='reg')

# %%
# Preprocessing Input data
XX = dataxx.iloc[:, 0]
YY = dataxx.iloc[:, 1]
plt.scatter(XX, YY)
plt.show()

# %%
Y_predx = lm2.coef_*XX +  lm2.intercept_
#Y_predx = 1.4777440851889796*XX + 0.08893651996682016

plt.scatter(XX, YY) 
plt.plot([min(XX), max(XX)], [min(Y_predx), max(Y_predx)], color='red')  # regression line
plt.show()

# %%
#Y_predx = lm2.coef_*XX +  lm2.intercept_
Y_predx = 1.4777440851889796*XX + 0.08893651996682016

plt.scatter(XX, YY) 
plt.plot([min(XX), max(XX)], [min(Y_predx), max(Y_predx)], color='red')  # regression line
plt.show()
